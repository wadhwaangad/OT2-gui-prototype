# %%
import sys
import os

# Add the upstream directory to sys.path
upstream_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if upstream_dir not in sys.path:
    sys.path.insert(0, upstream_dir)


import json
import os
from typing import Dict, Any, List, Optional, Tuple
import Model.globals as globals
import paths
import requests
from Model.ot2_api import OpentronsAPI

# %%
globals.robot_api = OpentronsAPI()

# %%
globals.robot_api.get_run_info()
# Out:
# Total number of runs: 20
# Current run ID: a99ca2ca-7183-4f10-a5bf-2498aa44f30a
# Current run status: idle
# [{'id': '681a7283-eac7-4221-9d62-b05355893392',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-23T20:16:09.772934Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'b24c667a-702c-4d6d-b1df-2eccf6139be9',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-24T01:10:23.383478Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'ef31c82b-66aa-4781-b9e0-3a1320a70804',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-24T07:00:34.481464Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': '0c570c52-24ca-41f3-8706-c01128eae8ba',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-24T10:44:32.597082Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': '0faf2d7d-fc85-497d-8801-a10688c01b6f',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-24T14:42:51.464725Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'b3dffe2e-4c50-4dc6-b9e7-cbdc03ab305d',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-24T20:09:19.249620Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': '7216d62f-cb99-4731-ae56-6c67add85796',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-24T23:33:50.395294Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': '53ffd51e-2de5-4b57-9056-496a64a40776',
#   'ok': True,
#   'createdAt': '2025-05-25T02:04:28.243754Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [{'id': '66712d30-b243-4ee7-866b-ac3130edbbfe',
#     'pipetteName': 'p300_single_gen2',
#     'mount': 'left'}],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': [],
#   'completedAt': '2025-05-25T03:52:53.288766Z'},
#  {'id': '2adfdab5-f64e-42d4-8b24-747aa13acbf7',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-25T03:52:47.547490Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'a26017d1-c3f7-49df-b66b-fb8ad1beeb8e',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-25T06:39:07.496251Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': '2c812cd6-267e-40c9-a418-948673bd0369',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-25T10:09:03.282660Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'd9dc328d-c900-4f2f-86ed-b11c9b84bcae',
#   'ok': True,
#   'createdAt': '2025-05-25T13:09:12.431805Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [{'id': '151acfbc-d502-4fae-8590-8f1a938832cb',
#     'pipetteName': 'p300_single_gen2',
#     'mount': 'left'}],
#   'modules': [],
#   'labware': [{'id': '9637bb1c-2c01-4e07-aaff-78e9d8db028e',
#     'loadName': 'opentrons_96_tiprack_300ul',
#     'definitionUri': 'opentrons/opentrons_96_tiprack_300ul/1',
#     'location': {'slotName': '11'}},
#    {'id': 'a20dfedb-9d2c-4459-b193-c9b700720210',
#     'loadName': 'corning_6_wellplate_16.8ml_flat',
#     'definitionUri': 'opentrons/corning_6_wellplate_16.8ml_flat/1',
#     'location': {'slotName': '4'}},
#    {'id': '274820c3-7b75-4d4c-a088-768f214a2aa9',
#     'loadName': 'corning_96_wellplate_360ul_flat',
#     'definitionUri': 'opentrons/corning_96_wellplate_360ul_flat/1',
#     'location': {'slotName': '9'},
#     'offsetId': '1597dbf6-9096-458b-a0e2-e03f2c001b92'},
#    {'id': '14d0654c-951f-46a2-b9d0-83b2b5106cf0',
#     'loadName': 'vwr_96_tiprack_200ul_xl',
#     'definitionUri': 'custom_beta/vwr_96_tiprack_200ul_xl/1',
#     'location': {'slotName': '10'}},
#    {'id': '43facae2-c3be-4558-81c6-72828dac8d1e',
#     'loadName': 'corning_96_wellplate_360ul_flat',
#     'definitionUri': 'opentrons/corning_96_wellplate_360ul_flat/1',
#     'location': {'slotName': '5'},
#     'offsetId': '9e7d8e2e-d379-404d-a3e9-dc47b1a5f73d'}],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [{'id': '1597dbf6-9096-458b-a0e2-e03f2c001b92',
#     'createdAt': '2025-05-25T13:10:14.395456Z',
#     'definitionUri': 'opentrons/corning_96_wellplate_360ul_flat/1',
#     'location': {'slotName': '9'},
#     'vector': {'x': 0.0, 'y': 0.0, 'z': 65.0}},
#    {'id': '9e7d8e2e-d379-404d-a3e9-dc47b1a5f73d',
#     'createdAt': '2025-05-25T13:23:31.728329Z',
#     'definitionUri': 'opentrons/corning_96_wellplate_360ul_flat/1',
#     'location': {'slotName': '5'},
#     'vector': {'x': 0.0, 'y': 0.0, 'z': 65.0}}],
#   'runTimeParameters': [],
#   'outputFileIds': [],
#   'completedAt': '2025-05-25T16:58:05.946201Z'},
#  {'id': '1140d5dc-00c2-48dd-9eae-0a051c8cefc5',
#   'ok': True,
#   'createdAt': '2025-05-25T16:58:00.137738Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': [],
#   'completedAt': '2025-05-25T17:19:13.286406Z'},
#  {'id': '587679f8-06c2-4f5d-bacf-a83be0514459',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-25T17:19:07.460988Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'df5b4773-efa8-41ea-bdce-8403d1fe27bc',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-25T21:35:45.734760Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'bd7b94b1-4861-421f-a900-8a4dedb369b7',
#   'ok': True,
#   'createdAt': '2025-05-26T01:59:55.669773Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [{'id': 'fbe4238b-cfd7-44ba-9050-a02b45142381',
#     'pipetteName': 'p300_single_gen2',
#     'mount': 'left'}],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': [],
#   'completedAt': '2025-05-26T04:42:20.849853Z'},
#  {'id': '29f1ccad-c934-4534-8e2a-839d1014d55c',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-26T04:42:15.224196Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'f1972d97-e480-4240-b6ab-5d7cadf6c4b6',
#   'ok': False,
#   'dataError': {'id': 'RunDataError',
#    'title': 'Run Data Error',
#    'detail': 'There was no engine state data for this run.',
#    'meta': {'type': 'InvalidStoredData',
#     'code': '4008',
#     'message': 'There was no engine state data for this run.',
#     'detail': {},
#     'wrapping': []},
#    'errorCode': '4008'},
#   'createdAt': '2025-05-26T06:14:22.194787Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []},
#  {'id': 'e48da666-05b5-4dab-b0cf-256251a88c16',
#   'ok': True,
#   'createdAt': '2025-05-26T12:48:16.228322Z',
#   'status': 'stopped',
#   'current': False,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [{'id': 'f98c6f15-6483-4f3e-a673-91ae0b851a9b',
#     'pipetteName': 'p300_single_gen2',
#     'mount': 'left'}],
#   'modules': [],
#   'labware': [{'id': 'c3629b42-b3b7-44fd-a3fb-169b5ba7546f',
#     'loadName': 'opentrons_96_tiprack_300ul',
#     'definitionUri': 'opentrons/opentrons_96_tiprack_300ul/1',
#     'location': {'slotName': '11'}},
#    {'id': '5925e7cd-5154-4f5a-a90d-4bb97bb68296',
#     'loadName': 'vwr_96_tiprack_200ul_xl',
#     'definitionUri': 'custom_beta/vwr_96_tiprack_200ul_xl/1',
#     'location': {'slotName': '10'}},
#    {'id': 'cef94bcf-f5de-447e-ac8d-6ac95b45fe29',
#     'loadName': 'corning_6_wellplate_16.8ml_flat',
#     'definitionUri': 'opentrons/corning_6_wellplate_16.8ml_flat/1',
#     'location': {'slotName': '4'}},
#    {'id': '0d54a70e-3cb2-45b5-a9ee-a78a923c6ad2',
#     'loadName': 'corning_96_wellplate_360ul_flat',
#     'definitionUri': 'opentrons/corning_96_wellplate_360ul_flat/1',
#     'location': {'slotName': '5'},
#     'offsetId': 'e8fa6a40-e418-4105-8261-239ca9dcc9a0'}],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [{'id': 'e8fa6a40-e418-4105-8261-239ca9dcc9a0',
#     'createdAt': '2025-05-26T12:50:02.759802Z',
#     'definitionUri': 'opentrons/corning_96_wellplate_360ul_flat/1',
#     'location': {'slotName': '5'},
#     'vector': {'x': 0.0, 'y': 0.0, 'z': 65.0}}],
#   'runTimeParameters': [],
#   'outputFileIds': [],
#   'completedAt': '2025-05-26T13:55:25.996533Z'},
#  {'id': 'a99ca2ca-7183-4f10-a5bf-2498aa44f30a',
#   'ok': True,
#   'createdAt': '2025-05-26T13:55:20.139535Z',
#   'status': 'idle',
#   'current': True,
#   'actions': [],
#   'errors': [],
#   'hasEverEnteredErrorRecovery': False,
#   'pipettes': [],
#   'modules': [],
#   'labware': [],
#   'liquids': [],
#   'liquidClasses': [],
#   'labwareOffsets': [],
#   'runTimeParameters': [],
#   'outputFileIds': []}]

# %%
protocols_dir = os.path.join(paths.BASE_DIR, 'protocols')
json_files = [f for f in os.listdir(protocols_dir) if f.endswith('.json')]

if not json_files:
    print("No custom labware JSON files found.")

success = True
for json_file_name in json_files:
    custom_labware_path = os.path.join(protocols_dir, json_file_name)
    try:
        with open(custom_labware_path, 'r') as json_file:
            custom_labware = json.load(json_file)

        command_dict = {
            "data": custom_labware
        }
        command_payload = json.dumps(command_dict)

        url = globals.robot_api.get_url('runs') + f'/{globals.robot_api.run_id}/' + 'labware_definitions'
        r = requests.post(url=url, headers=globals.robot_api.HEADERS, params={"waitUntilComplete": True}, data=command_payload)
        if not r.ok:
            print(f"Failed to upload {json_file_name}: {r.text}")
            success = False
    except Exception as e:
        print(f"Error uploading {json_file_name}: {e}")
        success = False

# %%
r.ok
# Out:
# True

# %%
json.loads(r.text)
# Out:
# {'data': {'definitionUri': 'custom_beta/vwr_96_tiprack_200ul_xl/1'}}

# %%
json_files
# Out:
# ['vwr_96_tiprack_200ul.json', 'vwr_96_tiprack_200ul_xl.json']

# %%
custom_labware_path
# Out:
# 'C:\\Users\\ivand\\Desktop\\OT2-gui-prototype\\protocols\\vwr_96_tiprack_200ul_xl.json'

# %%
#Define a tip rack. This is the default tip rack for the robot.
TIP_RACK = "vwr_96_tiprack_200ul_xl"
#Load the tip rack. Slot = 1 by default.
globals.robot_api.load_labware(TIP_RACK, 10, namespace='custom_beta',verbose=True)
# Out:
# Labware ID:
# ea86436b-55ac-48d2-a025-b629b47aad23
# <Response [201]>
