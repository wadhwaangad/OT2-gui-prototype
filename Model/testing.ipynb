# %%
import sys
import os

# Add the upstream directory to sys.path
upstream_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if upstream_dir not in sys.path:
    sys.path.insert(0, upstream_dir)


import json
import os
from typing import Dict, Any, List, Optional, Tuple
import Model.globals as globals
import paths
import requests
from Model.ot2_api import OpentronsAPI

# %%
globals.robot_api = OpentronsAPI()

# %%
globals.robot_api.get_run_info()[-1]
# Out:
# Total number of runs: 20
# Current run ID: 8f6c3a74-01c2-4709-840e-367d2a8f6ff6
# Current run status: idle
# {'id': '8f6c3a74-01c2-4709-840e-367d2a8f6ff6',
#  'ok': True,
#  'createdAt': '2025-05-26T15:06:28.517267Z',
#  'status': 'idle',
#  'current': True,
#  'actions': [],
#  'errors': [],
#  'hasEverEnteredErrorRecovery': False,
#  'pipettes': [],
#  'modules': [],
#  'labware': [],
#  'liquids': [],
#  'liquidClasses': [],
#  'labwareOffsets': [],
#  'runTimeParameters': [],
#  'outputFileIds': []}

# %%
protocols_dir = os.path.join(paths.BASE_DIR, 'protocols')
json_files = [f for f in os.listdir(protocols_dir) if f.endswith('.json')]

if not json_files:
    print("No custom labware JSON files found.")

success = True
for json_file_name in json_files:
    custom_labware_path = os.path.join(protocols_dir, json_file_name)
    # try:
    with open(custom_labware_path, 'r') as json_file:
        custom_labware = json.load(json_file)

    #     command_dict = {
    #         "data": custom_labware
    #     }
    #     command_payload = json.dumps(command_dict)

    #     url = globals.robot_api.get_url('runs') + f'/{globals.robot_api.run_id}/' + 'labware_definitions'
    #     r = requests.post(url=url, headers=globals.robot_api.HEADERS, params={"waitUntilComplete": True}, data=command_payload)
    #     if not r.ok:
    #         print(f"Failed to upload {json_file_name}: {r.text}")
    #         success = False
    # except Exception as e:
    #     print(f"Error uploading {json_file_name}: {e}")
    #     success = False

# %%
custom_labware
# Out:
# {'ordering': [['A1', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1'],
#   ['A2', 'B2', 'C2', 'D2', 'E2', 'F2', 'G2', 'H2'],
#   ['A3', 'B3', 'C3', 'D3', 'E3', 'F3', 'G3', 'H3'],
#   ['A4', 'B4', 'C4', 'D4', 'E4', 'F4', 'G4', 'H4'],
#   ['A5', 'B5', 'C5', 'D5', 'E5', 'F5', 'G5', 'H5'],
#   ['A6', 'B6', 'C6', 'D6', 'E6', 'F6', 'G6', 'H6'],
#   ['A7', 'B7', 'C7', 'D7', 'E7', 'F7', 'G7', 'H7'],
#   ['A8', 'B8', 'C8', 'D8', 'E8', 'F8', 'G8', 'H8'],
#   ['A9', 'B9', 'C9', 'D9', 'E9', 'F9', 'G9', 'H9'],
#   ['A10', 'B10', 'C10', 'D10', 'E10', 'F10', 'G10', 'H10'],
#   ['A11', 'B11', 'C11', 'D11', 'E11', 'F11', 'G11', 'H11'],
#   ['A12', 'B12', 'C12', 'D12', 'E12', 'F12', 'G12', 'H12']],
#  'brand': {'brand': 'VWR', 'brandId': ['76635-638']},
#  'metadata': {'displayName': 'VWR 96 Tip Rack 200 µL XL',
#   'displayCategory': 'tipRack',
#   'displayVolumeUnits': 'µL',
#   'tags': []},
#  'dimensions': {'xDimension': 128, 'yDimension': 86, 'zDimension': 95.5},
#  'wells': {'A1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 74,
#    'z': 4.5},
#   'B1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 65,
#    'z': 4.5},
#   'C1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 56,
#    'z': 4.5},
#   'D1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 47,
#    'z': 4.5},
#   'E1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 38,
#    'z': 4.5},
#   'F1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 29,
#    'z': 4.5},
#   'G1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 20,
#    'z': 4.5},
#   'H1': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 14,
#    'y': 11,
#    'z': 4.5},
#   'A2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 74,
#    'z': 4.5},
#   'B2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 65,
#    'z': 4.5},
#   'C2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 56,
#    'z': 4.5},
#   'D2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 47,
#    'z': 4.5},
#   'E2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 38,
#    'z': 4.5},
#   'F2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 29,
#    'z': 4.5},
#   'G2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 20,
#    'z': 4.5},
#   'H2': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 23,
#    'y': 11,
#    'z': 4.5},
#   'A3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 74,
#    'z': 4.5},
#   'B3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 65,
#    'z': 4.5},
#   'C3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 56,
#    'z': 4.5},
#   'D3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 47,
#    'z': 4.5},
#   'E3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 38,
#    'z': 4.5},
#   'F3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 29,
#    'z': 4.5},
#   'G3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 20,
#    'z': 4.5},
#   'H3': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 32,
#    'y': 11,
#    'z': 4.5},
#   'A4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 74,
#    'z': 4.5},
#   'B4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 65,
#    'z': 4.5},
#   'C4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 56,
#    'z': 4.5},
#   'D4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 47,
#    'z': 4.5},
#   'E4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 38,
#    'z': 4.5},
#   'F4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 29,
#    'z': 4.5},
#   'G4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 20,
#    'z': 4.5},
#   'H4': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 41,
#    'y': 11,
#    'z': 4.5},
#   'A5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 74,
#    'z': 4.5},
#   'B5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 65,
#    'z': 4.5},
#   'C5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 56,
#    'z': 4.5},
#   'D5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 47,
#    'z': 4.5},
#   'E5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 38,
#    'z': 4.5},
#   'F5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 29,
#    'z': 4.5},
#   'G5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 20,
#    'z': 4.5},
#   'H5': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 50,
#    'y': 11,
#    'z': 4.5},
#   'A6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 74,
#    'z': 4.5},
#   'B6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 65,
#    'z': 4.5},
#   'C6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 56,
#    'z': 4.5},
#   'D6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 47,
#    'z': 4.5},
#   'E6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 38,
#    'z': 4.5},
#   'F6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 29,
#    'z': 4.5},
#   'G6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 20,
#    'z': 4.5},
#   'H6': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 59,
#    'y': 11,
#    'z': 4.5},
#   'A7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 74,
#    'z': 4.5},
#   'B7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 65,
#    'z': 4.5},
#   'C7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 56,
#    'z': 4.5},
#   'D7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 47,
#    'z': 4.5},
#   'E7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 38,
#    'z': 4.5},
#   'F7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 29,
#    'z': 4.5},
#   'G7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 20,
#    'z': 4.5},
#   'H7': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 68,
#    'y': 11,
#    'z': 4.5},
#   'A8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 74,
#    'z': 4.5},
#   'B8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 65,
#    'z': 4.5},
#   'C8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 56,
#    'z': 4.5},
#   'D8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 47,
#    'z': 4.5},
#   'E8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 38,
#    'z': 4.5},
#   'F8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 29,
#    'z': 4.5},
#   'G8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 20,
#    'z': 4.5},
#   'H8': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 77,
#    'y': 11,
#    'z': 4.5},
#   'A9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 74,
#    'z': 4.5},
#   'B9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 65,
#    'z': 4.5},
#   'C9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 56,
#    'z': 4.5},
#   'D9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 47,
#    'z': 4.5},
#   'E9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 38,
#    'z': 4.5},
#   'F9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 29,
#    'z': 4.5},
#   'G9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 20,
#    'z': 4.5},
#   'H9': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 86,
#    'y': 11,
#    'z': 4.5},
#   'A10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 74,
#    'z': 4.5},
#   'B10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 65,
#    'z': 4.5},
#   'C10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 56,
#    'z': 4.5},
#   'D10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 47,
#    'z': 4.5},
#   'E10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 38,
#    'z': 4.5},
#   'F10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 29,
#    'z': 4.5},
#   'G10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 20,
#    'z': 4.5},
#   'H10': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 95,
#    'y': 11,
#    'z': 4.5},
#   'A11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 74,
#    'z': 4.5},
#   'B11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 65,
#    'z': 4.5},
#   'C11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 56,
#    'z': 4.5},
#   'D11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 47,
#    'z': 4.5},
#   'E11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 38,
#    'z': 4.5},
#   'F11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 29,
#    'z': 4.5},
#   'G11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 20,
#    'z': 4.5},
#   'H11': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 104,
#    'y': 11,
#    'z': 4.5},
#   'A12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 74,
#    'z': 4.5},
#   'B12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 65,
#    'z': 4.5},
#   'C12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 56,
#    'z': 4.5},
#   'D12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 47,
#    'z': 4.5},
#   'E12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 38,
#    'z': 4.5},
#   'F12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 29,
#    'z': 4.5},
#   'G12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 20,
#    'z': 4.5},
#   'H12': {'depth': 91,
#    'totalLiquidVolume': 200,
#    'shape': 'circular',
#    'diameter': 5,
#    'x': 113,
#    'y': 11,
#    'z': 4.5}},
#  'groups': [{'metadata': {},
#    'wells': ['A1',
#     'B1',
#     'C1',
#     'D1',
#     'E1',
#     'F1',
#     'G1',
#     'H1',
#     'A2',
#     'B2',
#     'C2',
#     'D2',
#     'E2',
#     'F2',
#     'G2',
#     'H2',
#     'A3',
#     'B3',
#     'C3',
#     'D3',
#     'E3',
#     'F3',
#     'G3',
#     'H3',
#     'A4',
#     'B4',
#     'C4',
#     'D4',
#     'E4',
#     'F4',
#     'G4',
#     'H4',
#     'A5',
#     'B5',
#     'C5',
#     'D5',
#     'E5',
#     'F5',
#     'G5',
#     'H5',
#     'A6',
#     'B6',
#     'C6',
#     'D6',
#     'E6',
#     'F6',
#     'G6',
#     'H6',
#     'A7',
#     'B7',
#     'C7',
#     'D7',
#     'E7',
#     'F7',
#     'G7',
#     'H7',
#     'A8',
#     'B8',
#     'C8',
#     'D8',
#     'E8',
#     'F8',
#     'G8',
#     'H8',
#     'A9',
#     'B9',
#     'C9',
#     'D9',
#     'E9',
#     'F9',
#     'G9',
#     'H9',
#     'A10',
#     'B10',
#     'C10',
#     'D10',
#     'E10',
#     'F10',
#     'G10',
#     'H10',
#     'A11',
#     'B11',
#     'C11',
#     'D11',
#     'E11',
#     'F11',
#     'G11',
#     'H11',
#     'A12',
#     'B12',
#     'C12',
#     'D12',
#     'E12',
#     'F12',
#     'G12',
#     'H12']}],
#  'parameters': {'format': 'irregular',
#   'quirks': [],
#   'isTiprack': True,
#   'tipLength': 91,
#   'isMagneticModuleCompatible': False,
#   'loadName': 'vwr_96_tiprack_200ul_xl'},
#  'namespace': 'custom_beta',
#  'version': 1,
#  'schemaVersion': 2,
#  'cornerOffsetFromSlot': {'x': 0, 'y': 0, 'z': 0}}

# %%
r.ok
# Out:
# True

# %%
json.loads(r.text)
# Out:
# {'data': {'definitionUri': 'custom_beta/vwr_96_tiprack_200ul_xl/1'}}

# %%
json_files
# Out:
# ['vwr_96_tiprack_200ul.json', 'vwr_96_tiprack_200ul_xl.json']

# %%
custom_labware_path
# Out:
# 'C:\\Users\\ivand\\Desktop\\OT2-gui-prototype\\protocols\\vwr_96_tiprack_200ul_xl.json'

# %%
#Define a tip rack. This is the default tip rack for the robot.
TIP_RACK = "vwr_96_tiprack_200ul_xl"
#Load the tip rack. Slot = 1 by default.
globals.robot_api.load_labware(TIP_RACK, 10, namespace='custom_beta',verbose=True)
# Out:
# Labware ID:
# ea86436b-55ac-48d2-a025-b629b47aad23
# <Response [201]>
